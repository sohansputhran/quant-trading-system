# %%
# importing necessary libraries
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import plotly.graph_objs as go

# %%
import sys
import os

# Add the project root directory to the Python path
sys.path.append(os.path.abspath(".."))

import data_analysis.Performance_Measurements as pm

# %%
tickers = ['AAPL', 'MSFT', 'GOOG', 'AMZN', 'TSLA']
ohlcv_data = {}

# %%
for ticker in tickers:
    temp = yf.download(ticker, period='1mo', interval='15m', multi_level_index=False)
    temp = temp[['Open', 'High', 'Low', 'Close', 'Volume']]
    temp.dropna(inplace=True)
    ohlcv_data[ticker] = temp
ohlcv_data
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# {'AAPL':                                  Open        High         Low       Close  \
#  Datetime
#  2025-04-17 13:30:00+00:00  197.149994  197.199997  194.729996  194.940994
#  2025-04-17 13:45:00+00:00  194.925003  196.269897  194.639999  196.059998
#  2025-04-17 14:00:00+00:00  196.080002  196.509995  195.550003  195.869995
#  2025-04-17 14:15:00+00:00  195.880005  196.279999  195.429993  195.639999
#  2025-04-17 14:30:00+00:00  195.690002  197.095001  194.419998  196.759995
#  ...                               ...         ...         ...         ...
#  2025-05-16 18:45:00+00:00  211.630005  211.799896  211.429993  211.524994
# ...

# %%
ohlcv_data['GOOG'].head(5)
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2025-04-17 13:30:00+00:00  156.638000  157.070007  155.880005  156.279999
# 2025-04-17 13:45:00+00:00  156.309998  156.419998  155.669998  156.020004
# 2025-04-17 14:00:00+00:00  156.014999  156.110001  155.210007  155.490005
# 2025-04-17 14:15:00+00:00  155.509995  155.539993  154.850006  154.898102
# 2025-04-17 14:30:00+00:00  154.929993  155.100006  150.899994  152.570007
#
#                             Volume
# Datetime
# 2025-04-17 13:30:00+00:00  2276906
# 2025-04-17 13:45:00+00:00   525632
# 2025-04-17 14:00:00+00:00   564037
# 2025-04-17 14:15:00+00:00   424787
# 2025-04-17 14:30:00+00:00  3294540

# %%
for ticker in tickers:
    # Calculate the CAGR for each ticker
    cagr = pm.CAGR(ohlcv_data[ticker])
    print(f"CAGR for {ticker}: {cagr:.2%}")
# Out:
# CAGR for AAPL: 8.34%
# CAGR for MSFT: 22.24%
# CAGR for GOOG: 7.10%
# CAGR for AMZN: 18.00%
# CAGR for TSLA: 44.49%

# %%
def Volatility(df):
    """
    Calculate the volatility of a stock based on its historical data.
    
    Parameters:
    df (pd.DataFrame): DataFrame containing the OHLCV data for the stock.

    Returns:
    float: The volatility of the specified stock.
    """
    # Calculate daily returns
    daily_returns = df['Close'].pct_change()
    
    # Calculate annualized volatility
    volatility = daily_returns.std() * np.sqrt(252)
    
    return volatility

# %%
for ticker in tickers:
    # Calculate the CAGR for each ticker
    volatility = Volatility(ohlcv_data[ticker])
    print(f"Volatility for {ticker}: {volatility:.2%}")
# Out:
# Volatility for AAPL: 7.18%
# Volatility for MSFT: 8.58%
# Volatility for GOOG: 7.51%
# Volatility for AMZN: 9.71%
# Volatility for TSLA: 12.60%
